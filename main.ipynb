# %% [markdown]
# <a href="https://colab.research.google.com/github/ambarja/google-building-footprints/blob/main/main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
import pandas as pd
from shapely.wkt import loads

# %%
# Reading the TSV file
df = pd.read_csv('/content/91f_buildings.csv')
df.head()
# Out:
#    latitude  longitude  area_in_meters  confidence  \
# 0 -3.756233 -73.267477        104.1534      0.8488
# 1 -2.859937 -67.770798        142.4813      0.8116
# 2 -4.118227 -70.052294          5.7157      0.6600
# 3 -3.775060 -73.263188         52.7939      0.8336
# 4 -3.469642 -69.006747         82.8554      0.7085
#
#                                             geometry full_plus_code
# 0  POLYGON((-73.2674095515271 -3.7562151592298, -...  67886PVM+G22P
# 1  POLYGON((-67.770787210052 -2.86000691847003, -...  679J46RH+2MGF
# 2  POLYGON((-70.0522816534101 -4.1182361844317, -...  677FVWJX+P34W
# 3  POLYGON((-73.2631428770845 -3.77504748979487, ...  67886PFP+XPFQ
# 4  POLYGON((-69.0067104 -3.4696897, -69.0067133 -...  678GGXJV+48R6

# %%
# CSV to geopandas object
df["geometry"] = df["geometry"].apply(lambda x: loads(x))
gdf = gpd.GeoDataFrame(df, geometry="geometry", crs="EPSG:4326")
# gdf.head()

# %%
gdf.to_file('/content/91f_buildings.gpkg')
